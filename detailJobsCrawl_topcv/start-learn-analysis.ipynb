# %%
import pandas as pd
import psycopg2
import os
from dotenv import load_dotenv
print("✅ Tất cả các thư viện cần thiết đã được import thành công!")
# Out:
# ✅ Tất cả các thư viện cần thiết đã được import thành công!

# %%
load_dotenv(dotenv_path='/home/kiet/gkinhere/jobs-pipeline-analysis/.env')
print("Đã tải các biến môi trường từ file .env")

db_name = os.getenv()
# Out:
# Đã tải các biến môi trường từ file .env
